# %%
! pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
#importando las libretas necesarias ara el analisis de la GEIH
import pandas as pd

# %%
#leyendo los datos de la geih
df_cgsse = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/4b59127d2e9b21bf6bf85a07aeed15e0cd04fd08/Datos/GEIH2025/cgsse.CSV",encoding='latin',sep=';')

# %%
df_cgsse
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     10
# 1      20250626    6  2025     8238974            1      2      1     10
# 2      20250626    6  2025     8238975            1      1      1     10
# 3      20250626    6  2025     8238975            1      2      1     10
# 4      20250626    6  2025     8238975            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 67851  20250626    6  2025     8283060            1      1      1     10
# 67852  20250626    6  2025     8283060            1      2      1     10
# 67853  20250626    6  2025     8283062            1      1      1     10
# 67854  20250626    6  2025     8283062            1      2      1     10
# 67855  20250626    6  2025     8283062            1      3      1     10
#
#        AREA  CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  \
# ...

# %%
#leyendo datos fuerza de trabajo
df_FuerzaTrabajo = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/4b59127d2e9b21bf6bf85a07aeed15e0cd04fd08/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV", encoding = 'latin', sep=';')
df_FuerzaTrabajo
# Out:
# /tmp/ipykernel_71613/4180253119.py:2: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_FuerzaTrabajo = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/4b59127d2e9b21bf6bf85a07aeed15e0cd04fd08/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV", encoding = 'latin', sep=';')
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     50
# 1      20250626    6  2025     8238974            1      2      1     50
# 2      20250626    6  2025     8238975            1      1      1     50
# 3      20250626    6  2025     8238975            1      2      1     50
# 4      20250626    6  2025     8238975            1      3      1     50
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 54445  20250626    6  2025     8283060            1      1      1     50
# ...

# %%
#leyendo datos ocupados 
df_Ocupados = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/No%20ocupados.CSV", encoding='latin',sep=';')
df_Ocupados
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238975            1      2      1     70
# 1      20250626    6  2025     8238978            1      1      1     70
# 2      20250626    6  2025     8238980            1      2      1     70
# 3      20250626    6  2025     8238981            1      2      1     70
# 4      20250626    6  2025     8238983            1      2      1     70
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 24739  20250626    6  2025     8283056            1      1      1     70
# 24740  20250626    6  2025     8283059            1      1      1     70
# 24741  20250626    6  2025     8283060            1      1      1     70
# 24742  20250626    6  2025     8283062            1      2      1     70
# 24743  20250626    6  2025     8283062            1      3      1     70
#
#        AREA  CLASE  ...  P7360  P9460  P1519  P1883  P7422  P7422S1  \
# ...

# %%
df_cgsse= [['DIRECTORIO' , 'SECUENCIA_P' , 'ORDEN' , 'FEX_C18']]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df_cgsse [df_cgsse['DIRECTORIO']==8240107]
#
# TypeError: list indices must be integers or slices, not str
